# %%
import SimpleITK as sitk
from platipy.imaging import ImageVisualiser
from platipy.imaging.registration.linear import linear_registration, alignment_registration
from platipy.imaging.registration.utils import apply_transform, apply_linear_transform

# %%
image = sitk.ReadImage(".\PRHGD5257_LUNG\IMAGES\PRHGD5257_LUNG_2_CT_THORAX_GATED_2.nii.gz")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17032/2627377962.py in <module>
# ----> 1 image = sitk.ReadImage(".\PRHGD5257_LUNG\IMAGES\PRHGD5257_LUNG_0_CT_THORAX_GATED_2.nii.gz")
#
# e:\Github-Repos\PlatiPyDemo\venv\lib\site-packages\SimpleITK\extra.py in ReadImage(fileName, outputPixelType, imageIO)
#     344     reader.SetImageIO(imageIO)
#     345     reader.SetOutputPixelType(outputPixelType)
# --> 346     return reader.Execute()
#     347
#     348
#
# e:\Github-Repos\PlatiPyDemo\venv\lib\site-packages\SimpleITK\SimpleITK.py in Execute(self)
#    5777     def Execute(self):
#    5778         r"""Execute(ImageFileReader self) -> Image"""
# -> 5779         return _SimpleITK.ImageFileReader_Execute(self)
#    5780
#    5781     def ReadImageInformation(self):
#
# RuntimeError: Exception thrown in SimpleITK ImageFileReader_Execute: D:\a\1\sitk\Code\IO\src\sitkImageReaderBase.cxx:97:
# sitk::ERROR: The file ".\PRHGD5257_LUNG\IMAGES\PRHGD5257_LUNG_0_CT_THORAX_GATED_2.nii.gz" does not exist.

# %%
vis = ImageVisualiser(image)
fig = vis.show()
